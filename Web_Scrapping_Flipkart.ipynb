# %%
##You are tasked with scraping laptop data from Flipkart to analyse the market trends. 
##Your goal is to create a scraper that retrieves information about laptops from Flipkart's Electronics category, specifically focusing on brands, prices, ratings,and specifications(using BeautifulSoup).

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
url = 'https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_bed842c8-3a3c-4af6-8224-03871eacf60e_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics%7ELaptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y&page=1'
#url = 'https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_bed842c8-3a3c-4af6-8224-03871eacf60e_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics%7ELaptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y&page=2

# %%
r = requests.get(url)

# %%
data = r.content

# %%
content_r = BeautifulSoup(data, 'html.parser')

# %%
content_r
# Out:
# <!DOCTYPE html>
# ...

# %%
dis = content_r.find_all('div',class_='_3Ay6Sb')

# %%
rating = []
for data in content_r.findAll('div',class_='_3pLy-c row'):
    rati=data.find('div', attrs={'class':'_3LWZlK'})
    rating.append(rati.text)
    #print(rat.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-995bed659f90> in <module>
#       2 for data in content_r.findAll('div',class_='_3pLy-c row'):
#       3     rati=data.find('div', attrs={'class':'_3LWZlK'})
# ----> 4     rating.append(rati.text)
#       5     #print(rat.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
rating
# Out:
# [None, None, None, None, None, None, None, None]

# %%
spec = content_r.find_all('div',class_='fMghEO')

# %%
spec
# Out:
# []

# %%
for i in spec:
    print(i)

# %%
data_l = content_r.find_all('div', class_ = '_4rR01T')

# %%
for data in data_l:
    print(data.text)
# Out:
# Acer Aspire 7 Intel Core i5 12th Gen 12450H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA Ge...
# Acer Swift Go 14 AI Powered EVO Intel Core Ultra 5 125H - (16 GB/512 GB SSD/Windows 11 Home) SFG14-72T...
# SAMSUNG Galaxy Book 2 Intel Core i5 12th Gen 1235U - (8 GB/512 GB SSD/Windows 11 Home) NP550 Thin and ...
# HP 15s Intel Core i3 12th Gen 1215U - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq5007TU Thin and Light La...
# ASUS Vivobook 15 Intel Core i3 11th Gen 1115G4 - (8 GB/256 GB SSD/Windows 11 Home) X515EA-EJ312W Thin ...
# Lenovo V15 AMD Ryzen 3 Quad Core 7320U - (8 GB/512 GB SSD/Windows 11 Home) V15 G4 AMN 1 Thin and Light...
# DELL Intel Core i3 12th Gen 1215U - (8 GB/512 GB SSD/Windows 11 Home) New Inspiron 15 Laptop Thin and ...
# Acer Aspire 7 Intel Core i5 12th Gen 12450H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA G...
# Lenovo IdeaPad Slim1 AMD Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15ACL6 | 15ACL7 T...
# ...

# %%
Laptops = []
Prices = []
Actual_prices = []
Dis_off = []
rat = []
for i in range(1,81):
    url = 'https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_bed842c8-3a3c-4af6-8224-03871eacf60e_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics%7ELaptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y&page={m}'
    url = url.replace('{m}',str(i))
    #print('------------------------------1_-----------')
    #print(url)
    r = requests.get(url)
    #r
    data = r.content
    content_r = BeautifulSoup(data, 'html.parser')
    data_l = content_r.find_all('div', class_ = '_4rR01T')
    
    for m in data_l:
        #print('------------------------------')
        fir = m.text
        Laptops.append(fir)
        
    data_p = content_r.find_all('div', class_ = '_30jeq3 _1_WHN1')
    for n in data_p:
        #print('------------------------------')
        pri = n.text
        Prices.append(pri)
        
    data_a = content_r.find_all('div', class_ = '_3I9_wc _27UcVY')
    for o in data_a:
        act = o.text
        Actual_prices.append(act)
        
    dis = content_r.find_all('div',class_='_3Ay6Sb')
    for p in dis:
        dis_a = p.text
        Dis_off.append(dis_a)

# %%
len(Laptops)
# Out:
# 960

# %%
 url.replace('{m}','1')
# Out:
# 'https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_bed842c8-3a3c-4af6-8224-03871eacf60e_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics%7ELaptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y&page=1'

# %%
len(Prices)
# Out:
# 960

# %%
Laptops[1]
# Out:
# 'Acer Nitro V Intel Core i5 13th Gen 13420H - (16 GB/512 GB SSD/Windows 11 Home/6 GB Graphics/NVIDIA Ge...'

# %%
Laptops
# Out:
# ['Acer Predator Neo (2023) Intel Core i7 13th Gen 13700HX - (16 GB/1 TB SSD/Windows 11 Home/6 GB Graphic...',
#  'Acer Nitro V Intel Core i5 13th Gen 13420H - (16 GB/512 GB SSD/Windows 11 Home/6 GB Graphics/NVIDIA Ge...',
#  'SAMSUNG Galaxy Book 2 Intel Core i5 12th Gen 1235U - (8 GB/512 GB SSD/Windows 11 Home) NP550 Thin and ...',
#  'Lenovo V15 AMD Ryzen 3 Quad Core 7320U - (8 GB/512 GB SSD/Windows 11 Home) V15 G4 AMN 1 Thin and Light...',
#  'ZEBRONICS Pro Series Z Intel Core i5 12th Gen 1235U - (8 GB/512 GB SSD/Windows 11 Home) ZEB-NBC 4S Thi...',
#  'Acer Aspire 3 14 Metal Body Intel Core i3 12th Gen N305 - (8 GB/512 GB SSD/Windows 11 Pro) A314-36M Th...',
#  'Lenovo IdeaPad Slim1 AMD Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/Windows 11 Home) 15ACL6 | 15ACL7 T...',
#  'HP Victus AI Powered AMD Ryzen 7 Octa Core 7840HS - (16 GB/512 GB SSD/Windows 11 Home/6 GB Graphics/NV...',
# ...

# %%
len(Dis_off)
# Out:
# 1148

# %%
len(Actual_prices)
# Out:
# 948

# %%
Laptops_1 = []
Act_prices = []
Dis_off_1 = []
Dis_prices = []
for i in range(948):
    Laptops_1.append(Laptops[i])
    Dis_prices.append(Prices[i])
    Act_prices.append(Actual_prices[i])
    Dis_off_1.append(Dis_off[i])

# %%
pd.DataFrame({'Laptops_Name' : Laptops_1, 'Discounted_Price':Dis_prices, 'Actual_Prices':Act_prices,'Discount_offered':Dis_off_1})
# Out:
#                                           Laptops_Name Discounted_Price  \
# 0    HP OMEN Intel Core Ultra 7 155H - (16 GB/1 TB ...        ₹1,74,990
# 1    HP ENVY AMD Ryzen 5 Hexa Core 8640HS - (16 GB/...          ₹86,990
# 2    HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...          ₹37,400
# 3    SAMSUNG Galaxy Book 2 Intel Core i5 12th Gen 1...          ₹46,990
# 4    ASUS Vivobook 15 Intel Core i3 11th Gen 1115G4...          ₹28,990
# ..                                                 ...              ...
# 943  HP ENVY AMD Ryzen 7 Octa Core 8840HS - (16 GB/...          ₹96,990
# 944  HP Spectre x360 (2023) OLED Eyesafe Evo Intel ...        ₹1,85,990
# 945  Lenovo Lenovo IdeaPad Gaming 3 Intel Intel Cor...          ₹65,650
# 946  HP ENVY Intel Core Ultra 7 1st Gen 155U - (16 ...        ₹1,09,990
# 947  CHUWI Intel Celeron Dual Core 11th Gen N4020 -...          ₹16,990
#
#     Actual_Prices Discount_offered
# 0       ₹1,91,668           8% off
# ...

# %%
products = []
prices = []
apps = []
os = []
hd = []
sound = []
ratings = []
for i in range(1,81):
    url = 'https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&otracker=categorytree&fm=neo%2Fmerchandising&iid=M_bed842c8-3a3c-4af6-8224-03871eacf60e_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker=hp_rich_navigation_8_1.navigationCard.RICH_NAVIGATION_Electronics%7ELaptop%2Band%2BDesktop_34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_8_L1_view-all&cid=34WHNYFH5V2Y&page={m}'
    url = url.replace('{m}',str(i))
   
    r = requests.get(url)
    
    data = r.content
    content_r = BeautifulSoup(data, 'html.parser')
    for data in content_r.findAll('div',class_='_3pLy-c row'):
        names=data.find('div', attrs={'class':'_4rR01T'})
        price=data.find('div', attrs={'class':'_30jeq3 _1_WHN1'})
        rating=data.find('div', attrs={'class':'_3LWZlK'})
        specification = data.find('div', attrs={'class':'fMghEO'})
        
        for each in specification:
            col=each.find_all('li', attrs={'class':'rgWa7D'})
            app =col[0].text
            os_ = col[1].text
            hd_ = col[2].text
            sound_ = col[3].text
        products.append(names.text)
        #prices.append(price.text) 
        apps.append(app)
        os.append(os_) 
        hd.append(hd_)
        sound.append(sound_) 
        #ratings.append(rating.text)

# %%
len(apps)
# Out:
# 984

# %%
Pro = []
for i in products:
    Pro.append(i.split()[0])

# %%
Laptops_1 = []
Act_prices = []
Dis_off_1 = []
Dis_prices = []
app = []
Os = []
HD = []
soun = []
for i in range(948):
    Laptops_1.append(Pro[i])
    Dis_prices.append(Prices[i])
    Act_prices.append(Actual_prices[i])
    Dis_off_1.append(Dis_off[i])
    app.append(apps[i])
    Os.append(os[i])
    HD.append(hd[i])
    soun.append(sound[i])

# %%
len(Pro)
# Out:
# 984

# %%
data = pd.DataFrame({'Laptops_Name' : Laptops_1, 'Discounted_Price':Dis_prices, 'Actual_Prices':Act_prices,'Discount_offered':Dis_off_1, 'Processor':app,'RAM':Os,'Operating System':HD,'RAM':soun})

# %%
data.to_csv('laptop.csv', index=False)
